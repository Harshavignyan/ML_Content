# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshavignyan/ML_Content/blob/main/MarketBasketAnalysis_Assignmet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
pip install apyori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5974 sha256=84987457e33419c743532cf15b16364ffde49f040c5561151e82ba5ecdf558d8
#   Stored in directory: /root/.cache/pip/wheels/cb/f6/e1/57973c631d27efd1a2f375bd6a83b2a616c4021f24aab84080
# Successfully built apyori
# ...

# %%
from apyori import apriori

# %%
data = pd.read_csv("Retail.csv", encoding='latin-1')
# for encoding you can also use other type which is
# encoding="ISO-8859-1"

# %%
data.head()
# Out:
#                                           Unnamed: 0  Unnamed: 1  \
# 0                     Transactions from the Database         NaN
# 1      1 : { Pencils, Markers, Highlighters, Papers}         NaN
# 2                             2 : {Markers, Erasers}         NaN
# 3  3 : {Stapler Pins, Papers, Erasers, Card Holde...         NaN
# 4                 4 : {Papers, Erasers, Cad Holders}         NaN
#
#      Unnamed: 2                                   Unnamed: 3 Unnamed: 4  \
# 0           NaN  #Transactions in which\n the item is bought    Support
# 1       Pencils                                            2        0.2
# 2       Markers                                            6        0.6
# 3  Highlighters                                            3        0.3
# 4        Papers                                            4        0.4
#
#   Unnamed: 5
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
data.shape
# Out:
# (18, 6)

# %%
records = []
for i in range(1, 18):
    records.append([str(data.values[i, j]) for j in range(0, 6)])

# %%
print(type(records))
# Out:
# <class 'list'>

# %%
association_rules = apriori(records, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)

# %%
association_results = list(association_rules)

# %%
print("There are {} Relation derived.".format(len(association_results)))
# Out:
# There are 216 Relation derived.

# %% [markdown]
# # **Association Rules Derived**

# %%
for i in range(0, len(association_results)):
    print(association_results[i][0])
# Out:
# frozenset({'#Transactions in which\n the item is bought', 'Construct item-sets with items that satisfy minimum support'})
# frozenset({'#Transactions in which\n the item is bought', 'Support\nP(MarkersÇErasers)'})
# frozenset({'0.2', '1 : { Pencils, Markers, Highlighters, Papers}'})
# frozenset({'2', '0.2'})
# frozenset({'0.2', '7 : {Markers, Erasers}'})
# frozenset({'0.2', '9 : {StaplerPins, Post-it, Markers, Erasers}'})
# frozenset({'0.2', 'Card Holders'})
# frozenset({'0.2', 'Envelop'})
# frozenset({'0.2', 'Pencils'})
# frozenset({'3', '0.3'})
# frozenset({'0.3', '3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters}'})
# frozenset({'6 : {Envelop}', '0.3'})
# frozenset({'8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers}', '0.3'})
# frozenset({'0.3', 'Highlighters'})
# frozenset({'0.3', 'Post-it'})
# frozenset({'0.3', 'Stapler Pins'})
# frozenset({'0.4', '4'})
# frozenset({'0.4', '4 : {Papers, Erasers, Cad Holders}'})
# ...

# %% [markdown]
# # **Rules Generated**

# %%
for item in association_results:
    # first index of the inner list
    # Contains base item and add item
    pair = item[0]
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    # second index of the inner list
    print("Support: " + str(item[1]))

    # third index of the list located at 0th
    # of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: #Transactions in which
#  the item is bought -> Construct item-sets with items that satisfy minimum support
# Support: 0.058823529411764705
# Confidence: 1.0
# Lift: 17.0
# ...
# Rule: #Transactions in which
#  the item is bought -> Support
# P(MarkersÇErasers)
# Support: 0.058823529411764705
# Confidence: 1.0
# Lift: 17.0
# ...
# Rule: 0.2 -> 1 : { Pencils, Markers, Highlighters, Papers}
# Support: 0.058823529411764705
# Confidence: 0.3333333333333333
# Lift: 5.666666666666666
# ...
# Rule: 2 -> 0.2
# Support: 0.17647058823529413
# Confidence: 1.0
# Lift: 5.666666666666666
# ...
# Rule: 0.2 -> 7 : {Markers, Erasers}
# Support: 0.058823529411764705
# Confidence: 0.3333333333333333
# Lift: 5.666666666666666
# ...
# Rule: 0.2 -> 9 : {StaplerPins, Post-it, Markers, Erasers}
# Support: 0.058823529411764705
# Confidence: 0.3333333333333333
# Lift: 5.666666666666666
# ...
# Rule: 0.2 -> Card Holders
# Support: 0.058823529411764705
# Confidence: 0.3333333333333333
# Lift: 5.666666666666666
# ...
# Rule: 0.2 -> Envelop
# ...
